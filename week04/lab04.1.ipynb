# %%
import requests
import pandas as pd

# %%
# base_url = "https://archive-api.open-meteo.com/v1/archive"
# params = {}
# def weather_getter(lat, long, start, end, daily, temp_unit, temp):
#     """ Function takes in parameters for a place and returns their output from the Open Meteo API"""
